# %%
import pandas as pd
import numpy as np

# %%
# 불러오고 싶은 csv 파일의 열 이름만 저장하기
filename='서울교통공사_역별 일별 시간대별 승하차인원 정보_20230930.csv'
cols = pd.read_csv(filename, encoding='euc-kr', nrows=0).columns
cols
# Out:
# Index(['연번', '수송일자', '호선', '역번호', '역명', '승하차구분', '06시이전', '06-07시간대',
#        '07-08시간대', '08-09시간대', '09-10시간대', '10-11시간대', '11-12시간대', '12-13시간대',
#        '13-14시간대', '14-15시간대', '15-16시간대', '16-17시간대', '17-18시간대', '18-19시간대',
#        '19-20시간대', '20-21시간대', '21-22시간대', '22-23시간대', '23-24시간대', '24시이후'],
#       dtype='object')

# %%
# '연번' 제외한 열들 불러오기
seoulsubDF = pd.read_csv(filename, encoding='euc-kr', usecols=cols[1:])
seoulsubDF
# Out:
#               수송일자   호선   역번호   역명 승하차구분  06시이전  06-07시간대  07-08시간대  08-09시간대  \
# 0       2023-01-01  1호선   150  서울역    승차    215       145       231       594
# 1       2023-01-01  1호선   150  서울역    하차    154       636       595       939
# 2       2023-01-01  1호선   151   시청    승차     48        73       106       194
# 3       2023-01-01  1호선   151   시청    하차     64       247       293       463
# 4       2023-01-01  1호선   152   종각    승차    407       235       158       201
# ...            ...  ...   ...  ...   ...    ...       ...       ...       ...
# 148790  2023-09-30  8호선  2826   수진    하차      8         0         8        40
# 148791  2023-09-30  8호선  2827   모란    승차     39         0        39        34
# 148792  2023-09-30  8호선  2827   모란    하차      9         0         9        45
# 148793  2023-09-30  8호선  2828  남위례    승차     20         0        20        54
# 148794  2023-09-30  8호선  2828  남위례    하차     16         0        16        53
#
# ...

# %%
# 행 단위, 여러 열들의 합계 구하기
seoulsubDF.loc[:, '총합'] = seoulsubDF.loc[:, '06시이전':'24시이후'].sum(axis=1)
seoulsubDF
# Out:
#               수송일자   호선   역번호   역명 승하차구분  06시이전  06-07시간대  07-08시간대  08-09시간대  \
# 0       2023-01-01  1호선   150  서울역    승차    215       145       231       594
# 1       2023-01-01  1호선   150  서울역    하차    154       636       595       939
# 2       2023-01-01  1호선   151   시청    승차     48        73       106       194
# 3       2023-01-01  1호선   151   시청    하차     64       247       293       463
# 4       2023-01-01  1호선   152   종각    승차    407       235       158       201
# ...            ...  ...   ...  ...   ...    ...       ...       ...       ...
# 148790  2023-09-30  8호선  2826   수진    하차      8         0         8        40
# 148791  2023-09-30  8호선  2827   모란    승차     39         0        39        34
# 148792  2023-09-30  8호선  2827   모란    하차      9         0         9        45
# 148793  2023-09-30  8호선  2828  남위례    승차     20         0        20        54
# 148794  2023-09-30  8호선  2828  남위례    하차     16         0        16        53
#
# ...

# %%
count = seoulsubDF.shape[0]
count
# Out:
# 148795

# %%
df_total_count_of_perople = seoulsubDF['총합']

stations = set()

for i in range(count):
    stations.add(seoulsubDF.iloc[i]['역명'])

dict_count_of_people_by_stations = dict()

for station in stations:
    dict_count_of_people_by_stations[station] = 0
print(dict_count_of_people_by_stations)
# Out:
# {'신정네거리': 0, '충정로(경기대입구)': 0, '마들': 0, '매봉': 0, '오목교(목동운동장앞)': 0, '서대문': 0, '강동구청': 0, '종각': 0, '마포': 0, '망원': 0, '마천': 0, '미아사거리': 0, '금호': 0, '증산(명지대앞)': 0, '하계': 0, '여의나루': 0, '학여울': 0, '미사': 0, '건대입구': 0, '하남검단산': 0, '역삼': 0, '거여': 0, '독바위': 0, '안암(고대병원앞)': 0, '신금호': 0, '구의(광진구청)': 0, '수유(강북구청)': 0, '동대문': 0, '용마산(용마폭포공원)': 0, '중곡': 0, '신대방삼거리': 0, '고속터미널': 0, '애오개': 0, '성신여대입구(돈암)': 0, '우장산': 0, '하남풍산': 0, '월곡(동덕여대)': 0, '춘의': 0, '사당': 0, '몽촌토성(평화의문)': 0, '까치울': 0, '도곡': 0, '장승배기': 0, '부천시청': 0, '개롱': 0, '한양대': 0, '불광': 0, '광화문(세종문화회관)': 0, '고덕': 0, '대치': 0, '경복궁(정부서울청사)': 0, '상수': 0, '신풍': 0, '천왕': 0, '송파': 0, '모란': 0, '용두(동대문구청)': 0, '장지': 0, '김포공항': 0, '신흥': 0, '신촌': 0, '합정': 0, '공릉(서울과학기술대)': 0, '용답': 0, '둔촌동': 0, '수서': 0, '광나루(장신대)': 0, '수진': 0, '송정': 0, '올림픽공원(한국체대)': 0, '문래': 0, '숭실대입구(살피재)': 0, '산성': 0, '내방': 0, '신대방': 0, '문정': 0, '서울역': 0, '대청': 0, '무악재': 0, '당고개': 0, '강동': 0, '가락시장': 0, '청구': 0, '성수': 0, '버티고개': 0, '동묘앞': 0, '방배': 0, '이촌(국립중앙박물관)': 0, '영등포시장': 0, '동대입구
# ...

# %%
for i in range(count):
    current = seoulsubDF.iloc[i]
    dict_count_of_people_by_stations[current['역명']] += current['총합']
print(dict_count_of_people_by_stations)
# Out:
# {'신정네거리': 5406924, '충정로(경기대입구)': 7441203, '마들': 6545979, '매봉': 6007569, '오목교(목동운동장앞)': 11433551, '서대문': 9640329, '강동구청': 5344874, '종각': 19213514, '마포': 7267287, '망원': 8008440, '마천': 3767589, '미아사거리': 13812043, '금호': 4020661, '증산(명지대앞)': 5152092, '하계': 9008486, '여의나루': 7903257, '학여울': 1323093, '미사': 8939538, '건대입구': 27248889, '하남검단산': 3378485, '역삼': 26113170, '거여': 5078536, '독바위': 1472534, '안암(고대병원앞)': 6469523, '신금호': 3330658, '구의(광진구청)': 12133484, '수유(강북구청)': 17762898, '동대문': 16437134, '용마산(용마폭포공원)': 3032359, '중곡': 5361896, '신대방삼거리': 7521414, '고속터미널': 34013276, '애오개': 3369189, '성신여대입구(돈암)': 10792567, '우장산': 7440985, '하남풍산': 2268071, '월곡(동덕여대)': 6122805, '춘의': 0, '사당': 34826436, '몽촌토성(평화의문)': 3459706, '까치울': 0, '도곡': 2669011, '장승배기': 4662373, '부천시청': 0, '개롱': 3390568, '한양대': 5659711, '불광': 11295724, '광화문(세종문화회관)': 16559547, '고덕': 5067339, '대치': 6261531, '경복궁(정부서울청사)': 12872556, '상수': 5675516, '신풍': 5822117, '천왕': 5706106, '송파': 4631133, '모란': 2387129, '용두(동대문구청)': 1274479, '장지': 85702
# ...

# %%
seoulsubDF.dtypes[seoulsubDF.dtypes == 'int64']
# Out:
# 역번호         int64
# 06시이전       int64
# 06-07시간대    int64
# 07-08시간대    int64
# 08-09시간대    int64
# 09-10시간대    int64
# 10-11시간대    int64
# 11-12시간대    int64
# 12-13시간대    int64
# 13-14시간대    int64
# 14-15시간대    int64
# 15-16시간대    int64
# 16-17시간대    int64
# 17-18시간대    int64
# 18-19시간대    int64
# 19-20시간대    int64
# 20-21시간대    int64
# 21-22시간대    int64
# 22-23시간대    int64
# 23-24시간대    int64
# 24시이후       int64
# 총합          int64
# dtype: object

# %%
seoulsubDF.dtypes == 'int64'
# Out:
# 수송일자        False
# 호선          False
# 역번호          True
# 역명          False
# 승하차구분       False
# 06시이전        True
# 06-07시간대     True
# 07-08시간대     True
# 08-09시간대     True
# 09-10시간대     True
# 10-11시간대     True
# 11-12시간대     True
# 12-13시간대     True
# 13-14시간대     True
# 14-15시간대     True
# 15-16시간대     True
# 16-17시간대     True
# 17-18시간대     True
# 18-19시간대     True
# 19-20시간대     True
# 20-21시간대     True
# 21-22시간대     True
# 22-23시간대     True
# 23-24시간대     True
# 24시이후        True
# 총합           True
# dtype: bool
